# %%
import numpy as np
"""
VER EJERCICIO 8-AUGUSTO 2020
"""

# %%
from IPython.display import Image
Image(filename='dendo.png')

# %%
"""
Pasos: 
1-Crear el vector Z: el GROUNDTRUTH: el cluster lo indica el color de la muestra (habran varios clusters)
2-Crear el vector Q: la PREDICCION: lo creas mirando el dendo cortado o lo que haiga
3-Creas la matriz que SIEMPRE ES KxM donde K=numero clusters gorundtruth, M=numero de clusters prediccion
La matriz se crea viendo si la clase, por ejemplo, y=0 está en el K=1 y M=1 etc.. asi con todo
4-Vectores -> nz=vector de suma de las filas, nq=vector suma de las columnas
5-numero de pares: N (numero de muetras) (N-1) / 2

6- Crear S: SUMA de N(N-1)/2 de CADA VALOR DE LA MATRIZ
7-Nz: N(N-1)/2 de cada valor de nz
8-Nq: N(N-1)/2 de cada valor de nq
9-D=n_pares - nq- nz + S

10- Formula final: 
J = S/0.5*N(N-1)  - D

"""
