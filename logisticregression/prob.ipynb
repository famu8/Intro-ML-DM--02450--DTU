# %%
from IPython.display import Image

# %%
Image(filename='sigmoide.png')

# %%
Image(filename='problog.png')

# %%
import numpy as np
# basicamente mete los valores de los weights donde toque y calcula
prob = 1 / 1 + np.exp(- (0.31 + (-0.06*4) + (0.07 * (-4)))  )
print(prob*100)
# Out:
# 223.3678059956743

# %%
import numpy as np

# %%
v1 = np.array([-0.93, 1.72])
v2 = np.array([1, 1])
out = 0.69
sigma = out / (np.dot(v2.T,v1))
sigma
# Out:
# 0.8734177215189873

# %%
Image(filename='pesos.png')

# %% [markdown]
# el w1 de lospesos es el bias (418.94), vas cogiedno valores de ambas predicciones y
# tienen que concordar con la linea negra, si hace falta introduce mas inputs simplemente añade
# + (peso*input)

# %%
prob = 1 / (1 + np.exp(-(0.72 + ( 3.13 * (0) ) + ((0.25) *(-4))  )))
print("porcentaje de prob: ", prob)
# Out:
# porcentaje de prob:  0.43045377606077095

# %%
prob = 1 / (1 + np.exp(-(418.94 + ( -26.12 * 14 )  )))
print("porcentaje de prob: ", prob*100)
