# %%
"""
The support of an itemset containing multiple items is limited by the item with the lowest support. 
Osea para obetener el mayor support hay que encontrar el producto que tiene menos muestras
en el dataset. en esta caso la humedad

Resultado: n_humedad / N = 0.415
"""
# Out:
# '\nThe support of an itemset containing multiple items is limited by the item with the lowest support. \nOsea para obetener el mayor support hay que encontrar el producto que tiene menos muestras\nen el dataset. en esta caso la humedad\n\nResultado: n_humedad / N = 0.415\n'

# %%
from IPython.display import Image
Image(filename='basket1.png')

# %%
Image(filename='basket2.png')
