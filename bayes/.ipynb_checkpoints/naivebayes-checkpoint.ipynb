# %%
from IPython.display import Image

# %%
Image(filename='bayes.png')

# %%
"""
lo de arriba es la formula del Naive Bayes, es como la formula de bayes normal pero
las probabilidades se multiplican
Numerador: se multiplica todo. ES LA PROBABILIDAD DE POR EJEMPLO SER HOMBRE DADO ALGO 
Denominador: aqui es: PROB DE DADO ESE ALGO SER MUJER (todo multiplicado como arriba) + NUMERADOR

Al final es como Bayes practicamente: hombre/hombre+mujer

Si te piden el numero minimo de evaluacions para una normal distribution es CM donde C=numero de clases
(en este caso de y, q son 3) y M son el numero de caracteristicas (M=8). resultado=3*8=24
"""

# %%
Image(filename='697.jpg')

# %% [markdown]
# ## mas ejemplo de naive

# %%
"""
En este ejemplo se te dan dos condiciones es decir, dado x e y que pase z 
EN este caso es dad un jugaro alto y delgado que marque muchos puntos 
Pues como es naive bayes haces: P(Muchos puntos | alto, delgado)? 
--> P(alto|muchos puntos)*P(delgado|muchso pnts)*P(muchos puntos)
Y en el denominador seria P(delgado|medios puntos)*P(alto|medios)*P(medios)
Y tambien lo mismo para pocos puntos
"""

# %%
Image(filename='naive.png')

# %%
Image(filename='naive2.png')
