# %%
from IPython.display import Image

# %%
Image(filename='pove.png')

# %%
Image(filename='pove2.png')

# %%
"""
Como en este caso hay 0 veces que las columnas f2 y f3 tengan un 1 A LA VEZ. Es 0 arriba
"""
# Out:
# '\nComo en este caso hay 0 veces que las columnas f2 y f3 tengan un 1 A LA VEZ. Es 0 arriba\n'
