# %%
from IPython.display import Image
"""
Miras donde las columnas f coinciden en 1 y haces todas las 
combinaciones posibles entre ellas
abajo la correcta es la C
----------
nominal->ordinal->interval->ratio(puede haber 0)
"""
# Out:
# '\nMiras donde las columnas f coinciden en 1 y haces todas las \ncombinaciones posibles entre ellas\nabajo la correcta es la C\n----------\nnominal->ordinal->interval->ratio(puede haber 0)\n'

# %%
Image(filename='1hoy.png')

# %%
Image(filename='2hoy.png')
